# %% [markdown]
# # Challenge 2

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.options.plotting.backend = "plotly"

# %% [markdown]
# #### 1. Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('data/titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### 2. Explore the titanic dataset using Pandas dtypes

# %%
data_types = titanic.dtypes

print(data_types)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### 3. What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
numerical_var = titanic.select_dtypes(include = ['int64', 'float64'])

print('Numerical var:')

print(numerical_var.columns)
# Out:
# Numerical var:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
categorical_var = titanic.select_dtypes(include=['object'])

print("Categorical variables:")

print(categorical_var.columns)
# Out:
# Categorical variables:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### 4. Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
import matplotlib.pyplot as plt


plt.style = ('classic')

plt.figure(figsize = (12, 6))

plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# #### 5. Use the appropriate visulalization to show the distribution of the column `Age`

# %%
plt.hist(titanic['Age'], bins=20, edgecolor='black')

plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')

plt.show()

# %% [markdown]
# #### 6. Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 6))

bins = [10, 20, 50]

for i in range(3):
    ax = axes[i] 
    ax.hist(titanic['Age'], bins = bins[i], edgecolor ='black')
    ax.set_xlabel('Age')
    ax.set_ylabel('Count')
    ax.set_title(f'Age Distribution(Bins:{bins[i]}')


plt.tight_layout()


plt.show()

# %% [markdown]
# #### 7. Whether the bin size affects your plot? Why?

# %%
# Yes, it affects the plot. More bins give more detailed distribution while fewer bins show more general distribution.

# %% [markdown]
# #### 8. Use seaborn to show the distribution of the column `Age`

# %%
sns.set_style('darkgrid')

sns.histplot(titanic, x='Age', kde=True)

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #### 9. Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
gender_counts = titanic['Gender'].value_counts()

plt.bar(gender_counts.index, gender_counts.values)

plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
sns.countplot(titanic, x='Gender')

plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #### 10. Use the appropriate plot to visualize the column `Pclass`

# %%
sns.countplot(titanic, x = 'Pclass')

plt.title('Pclass Distribution')
plt.xlabel('Pclass')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# #### 11. We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
sns.boxplot(titanic, y = 'Age')

plt.title('Statistics Summarymof Age')
plt.ylabel('Age')

plt.show()

# %% [markdown]
# #### 12. What does the previous plot tell you about the feature `Age`? Comment.

# %%
# The median Age is around the 30 years. Also, we can see outliers of +60 years.

# %% [markdown]
# #### 13. Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
plt.hist(titanic['Age'], bins = 20, edgecolor = 'black')

plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')

plt.show()

# %% [markdown]
# #### 14. What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
# We can see the majority of the passengers had similar age, younger.

# %% [markdown]
# #### 15. We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
sns.regplot(titanic, x = 'Age', y = 'Fare')

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Fare vs Age')

plt.show()

# %%
plt.scatter(titanic['Age'], titanic['Fare'])

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Fare vs Age')

plt.show()

# %% [markdown]
# #### 16. Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
correlation_matrix = titanic.corr()

mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', mask = mask)
plt.title('Correlation Matrix of Titanic Features (with Mask)')

plt.show()
# Out:
# /var/folders/m2/4q6f2lrs02v9sy_2gm7gqvd40000gn/T/ipykernel_70127/700455805.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# #### 17. According to the previous plot, what are the most correlated feature? Comment.

# %%
# Fare and Pclass with a correlation of -0.56. Passengers in hiher class paid higher fares.

# %% [markdown]
# #### 18. Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
sns.boxplot(titanic, x ='Pclass', y ='Age')

plt.title('Summary Statistics of Age by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Age')

plt.show()

# %% [markdown]
# #### 19. Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
x = sns.FacetGrid(titanic, col = 'Gender')

x.map(plt.hist, 'Age')

x.fig.suptitle('Distribution of Age by Gender')
x.set_axis_labels('Age', 'Count')

plt.tight_layout()

plt.show()

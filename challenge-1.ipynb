# %% [markdown]
# # Challenge 1

# %% [markdown]
# In this lab you will partner with another student to conduct **[pair programming](https://en.wikipedia.org/wiki/Pair_programming)**. In the next 60 minutes there will be 2 coding sessions of 30 minutes each. In each sessoin, one student will be the **driver** to write the code to solve the problem while the other student will be the **observer** to watch and review. There will be several iterations of your code because the observer will help the driver review the codes and make improvements until the 15 minute session ends. After the coding session ends, the driver and observer will switch roles.

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime

# %% [markdown]
# ## Preparation
#
# #### Import the `Fitbit2.csv` file and name your dataset `fitbit`

# %%
fitbit=pd.read_csv('data/Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# 0               1680             384                   26                23
# 1               2248             454                   35                21
# 2               1719             387                   46                25
# 3               9620             311                   31                21
# 4               7360             407                   65                44
#
#    LengthOfRestInMinutes  Distance_miles      Days  Days_encoded  \
# 0                    417        0.403891    Friday           4.0
# 1                    491        8.767545  Saturday           5.0
# 2                    436        6.567891    Sunday           6.0
# 3                    350        3.119282    Monday           0.0
# 4                    491        2.317714   Tuesday           1.0
#
#    Work_or_Weekend  Hours Sleep  Sleep efficiency  Yesterday_sleep  \
# 0                1     6.400000         92.086331         0.000000
# 1                0     7.566667         92.464358         6.400000
# 2                0     6.450000         88.761468         7.566667
# 3                1     5.183333         88.857143         6.450000
# 4                1     6.783333         82.892057         5.183333
#
#    Yesterday_sleep_efficiency Months  Months_encoded
# 0                    0.000000    May               5
# 1                   92.086331    May               5
# 2                   92.464358    May               5
# 3                   88.761468    May               5
# 4                   88.857143    May               5

# %% [markdown]
# ## Coding Session I - 30 minutes
#
# From the Fitbit data, we want to visually understand:
#
# 1. **How the average number of steps change by month. Use the appropriate visualization to show the median steps by month?**
# 1. **Is Fitbitter more active on weekend or workdays?**
#
# ##### All plots must be in the same jupyter notebook cell.
#
# Hints:
#
# - Use `Months_encoded` and `Week_or Weekend` columns
# - Use `matplolib.pyplot` object oriented API
# - Set your size figure to `12,4`
# - Explore `plt.sca`
# - Explore `plt.xticks`
# - Save your figures

# %%
dictio= {"January":1, "February":2, "March":3, "April":4, "May":5, "June":6, "July":7, "August":8, "September":9, "October":10, "November":11, "December":12}

df1=fitbit.groupby(['Months']).mean()["Steps"].reset_index()


df1["Mes_num"]= df1["Months"].apply(lambda x: dictio[x])
fitbit.head()
df1= df1.sort_values("Mes_num")
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_1128\1596052897.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1=fitbit.groupby(['Months']).mean()["Steps"].reset_index()

# %%
ax = plt.axes() # para poder cambiar el estilo de los ejes

ax.set_facecolor("white") # poner el fondo en blanco

ax.spines['bottom'].set_color('black') # color del eje x
ax.spines['top'].set_color('white') # color del eje de arriba
ax.spines['right'].set_color('white') # color del eje de la derecha
ax.spines['left'].set_color('black') # color del eje y

plt.plot(df1["Months"],        # eje x
         df1["Steps"], # eje y
         color = "blue", # para cambiar el color de la línea
         linewidth = 2, # para cambiar el grosor de la línea
         marker = "o") # para poner los marcadores en nuestra línea
meses = [datetime.date(2000, m, 1).strftime('%B') for m in range(1, 13)]

plt.xlabel("mes") # para poner etiqueta en el eje x
plt.ylabel("steps") # para poner etiqueta en el eje y
plt.xticks(df1["Months"], meses, rotation=45) # modificar los nombres del eje X



plt.show();

# %%
fitbit = fitbit.rename(columns=lambda x: x.replace(" ", "_"))
fitbit["Work_or_Weekend"] = fitbit["Work_or_Weekend"].replace({0: "Weekends", 1: "Working_Days"})
fitbit.head()
# Out:
#          Date  Calorie_burned  Steps  Distance  Floors  Minutes_Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes_Lightly_Active  Minutes_Fairly_Active  Minutes_Very_Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity_Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# 0               1680             384                   26                23
# 1               2248             454                   35                21
# 2               1719             387                   46                25
# 3               9620             311                   31                21
# 4               7360             407                   65                44
#
#    LengthOfRestInMinutes  Distance_miles      Days  Days_encoded  \
# 0                    417        0.403891    Friday           4.0
# 1                    491        8.767545  Saturday           5.0
# 2                    436        6.567891    Sunday           6.0
# 3                    350        3.119282    Monday           0.0
# 4                    491        2.317714   Tuesday           1.0
#
#   Work_or_Weekend  Hours_Sleep  Sleep_efficiency  Yesterday_sleep  \
# 0    Working_Days     6.400000         92.086331         0.000000
# 1        Weekends     7.566667         92.464358         6.400000
# 2        Weekends     6.450000         88.761468         7.566667
# 3    Working_Days     5.183333         88.857143         6.450000
# 4    Working_Days     6.783333         82.892057         5.183333
#
#    Yesterday_sleep_efficiency Months  Months_encoded
# 0                    0.000000    May               5
# 1                   92.086331    May               5
# 2                   92.464358    May               5
# 3                   88.761468    May               5
# 4                   88.857143    May               5

# %%
#Is Fitbitter more active on weekend or workdays?
#df1=fitbit.groupby(['Months']).mean()["Steps"].reset_index()



df2=fitbit.groupby(["Work_or_Weekend"]).mean()["Activity_Calories"].reset_index()


df2= df2.sort_values("Activity_Calories")
df2
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_1128\715559590.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2=fitbit.groupby(["Work_or_Weekend"]).mean()["Activity_Calories"].reset_index()
#   Work_or_Weekend  Activity_Calories
# 0        Weekends        1901.523810
# 1    Working_Days        2101.305344

# %%
# Driver 1 enter codes here

sns.barplot(data=df2,
           x="Work_or_Weekend",
            y="Activity_Calories",
          
           );

# %% [markdown]
# ## Coding Session II - 30 minutes
#
# **Write a loop to plot 3 scatter plots of the following features:**
#
# 1. **`Minutes Lightly Active`  vs `Steps`**
# 1. **`Minutes Very Active` vs `Steps`**
# 1. **`Minutes Sedentary` vs `Steps`**

# %%
fitbit.head()
# Out:
#          Date  Calorie_burned  Steps  Distance  Floors  Minutes_Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes_Lightly_Active  Minutes_Fairly_Active  Minutes_Very_Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity_Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# 0               1680             384                   26                23
# 1               2248             454                   35                21
# 2               1719             387                   46                25
# 3               9620             311                   31                21
# 4               7360             407                   65                44
#
#    LengthOfRestInMinutes  Distance_miles      Days  Days_encoded  \
# 0                    417        0.403891    Friday           4.0
# 1                    491        8.767545  Saturday           5.0
# 2                    436        6.567891    Sunday           6.0
# 3                    350        3.119282    Monday           0.0
# 4                    491        2.317714   Tuesday           1.0
#
#   Work_or_Weekend  Hours_Sleep  Sleep_efficiency  Yesterday_sleep  \
# 0    Working_Days     6.400000         92.086331         0.000000
# 1        Weekends     7.566667         92.464358         6.400000
# 2        Weekends     6.450000         88.761468         7.566667
# 3    Working_Days     5.183333         88.857143         6.450000
# 4    Working_Days     6.783333         82.892057         5.183333
#
#    Yesterday_sleep_efficiency Months  Months_encoded
# 0                    0.000000    May               5
# 1                   92.086331    May               5
# 2                   92.464358    May               5
# 3                   88.761468    May               5
# 4                   88.857143    May               5

# %%
# Driver 2 enter codes here
plt.scatter(fitbit["Minutes_Lightly_Active"], fitbit["Steps"])

# %%
sns.scatterplot(x='Minutes_Lightly_Active', 
                y='Steps', 
                data = fitbit ,
                
               palette = "cubehelix") # establecer el color de los puntos

plt.show();
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_1128\3143437599.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Minutes_Lightly_Active',

# %%
variables = ["Minutes_Sedentary" ,"Minutes_Lightly_Active" ,"Minutes_Very_Active"]
for variables in variables:
    plt.scatter(fitbit[variables],fitbit["Steps"])
    plt.xlabel(variables)
    plt.ylabel("Steps")
    plt.title("super grafico")
    plt.show()
